# %%
#pip install datasets

# %%
#from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
#ds = load_dataset("common-pile/caselaw_access_project")

# %%
import pandas as pd

df = pd.read_csv('legal_text_classification.csv')

# %%
df
# Out:
#          case_id   case_outcome  \
# 0          Case1          cited
# 1          Case2          cited
# 2          Case3          cited
# 3          Case4          cited
# 4          Case5          cited
# ...          ...            ...
# 24980  Case25203          cited
# 24981  Case25204          cited
# 24982  Case25205          cited
# 24983  Case25206  distinguished
# 24984  Case25207  distinguished
#
#                                               case_title  \
# 0      Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1      Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2      Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3      Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4      Dr Martens Australia Pty Ltd v Figgins Holding...
# ...                                                  ...
# 24980  Reches Pty Ltd v Tadiran Pty Ltd (1998) 85 FCR...
# 24981  Sir Lindsay Parkinson &amp; Co Ltd v Triplan L...
# 24982  Spiel v Commodity Brokers Australia Pty Ltd (I...
# 24983  Tullock Ltd v Walker (Unreported, Supreme Cour...
# 24984  Yandil Holdings Pty Ltd v Insurance Co of Nort...
#
#                                                case_text
# 0      Ordinarily that discretion will be exercised s...
# 1      The general principles governing the exercise ...
# 2      Ordinarily that discretion will be exercised s...
# 3      The general principles governing the exercise ...
# 4      The preceding general principles inform the ex...
# ...                                                  ...
# 24980  That is not confined to persons who control th...
# 24981  Once the threshold prescribed by s 1335 is sat...
# 24982  Once the threshold prescribed by s 1335 is sat...
# 24983  Given the extent to which Deumer stands to gai...
# 24984  In my view, it is clear that the Court may do ...
#
# [24985 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   case_id       24985 non-null  object
#  1   case_outcome  24985 non-null  object
#  2   case_title    24985 non-null  object
#  3   case_text     24809 non-null  object
# dtypes: object(4)
# memory usage: 780.9+ KB

# %%
df.describe()
# Out:
#           case_id case_outcome  \
# count       24985        24985
# unique      24985           10
# top     Case25207        cited
# freq            1        12219
#
#                                                case_title  \
# count                                               24985
# unique                                              18581
# top     Minister for Immigration and Ethnic Affairs v ...
# freq                                                   70
#
#                                                 case_text
# count                                               24809
# unique                                              17920
# top     submitted that this Court should hold that the...
# freq                                                   42

# %%
# Check for missing values
df.isnull().sum()
# Out:
# case_id           0
# case_outcome      0
# case_title        0
# case_text       176
# dtype: int64

# %%
# Remove rows with missing values
df.dropna(inplace=True)

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

nlp

# %%
# lowercase characters

df['p_case_title'] = df['case_title'].str.lower()
df['p_case_text'] = df['case_text'].str.lower()
df.head(10)
# Out:
#   case_id case_outcome                                         case_title  \
# 0   Case1        cited  Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1   Case2        cited  Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2   Case3        cited  Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3   Case4        cited  Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4   Case5        cited  Dr Martens Australia Pty Ltd v Figgins Holding...
# 5   Case6        cited  GEC Marconi Systems Pty Ltd v BHP Information ...
# 6   Case7        cited  John S Hayes &amp; Associates Pty Ltd v Kimber...
# 7   Case8        cited  Seven Network Limited v News Limited (2007) 24...
# 8   Case9      applied  Australian Broadcasting Corporation v O'Neill ...
# 9  Case10     followed  Hexal Australia Pty Ltd v Roche Therapeutics I...
#
#                                            case_text  \
# 0  Ordinarily that discretion will be exercised s...
# 1  The general principles governing the exercise ...
# 2  Ordinarily that discretion will be exercised s...
# 3  The general principles governing the exercise ...
# 4  The preceding general principles inform the ex...
# 5  I accept that the making of a rolled up offer ...
# 6  The preceding general principles inform the ex...
# 7  On the question of the level of unreasonablene...
# 8  recent decision of the High Court in Australia...
# 9  Hexal Australia Pty Ltd v Roche Therapeutics I...
#
#                                         p_case_title  \
# 0  alpine hardwood (aust) pty ltd v hardys pty lt...
# 1  black v lipovac [1998] fca 699 ; (1998) 217 al...
# 2  colgate palmolive co v cussons pty ltd (1993) ...
# 3  dais studio pty ltd v bullett creative pty ltd...
# 4  dr martens australia pty ltd v figgins holding...
# 5  gec marconi systems pty ltd v bhp information ...
# 6  john s hayes &amp; associates pty ltd v kimber...
# 7  seven network limited v news limited (2007) 24...
# 8  australian broadcasting corporation v o'neill ...
# 9  hexal australia pty ltd v roche therapeutics i...
#
#                                          p_case_text
# 0  ordinarily that discretion will be exercised s...
# 1  the general principles governing the exercise ...
# 2  ordinarily that discretion will be exercised s...
# 3  the general principles governing the exercise ...
# 4  the preceding general principles inform the ex...
# 5  i accept that the making of a rolled up offer ...
# 6  the preceding general principles inform the ex...
# 7  on the question of the level of unreasonablene...
# 8  recent decision of the high court in australia...
# 9  hexal australia pty ltd v roche therapeutics i...

# %%
import nltk
nltk.download('punkt_tab')
from nltk import word_tokenize

df['p_case_title'] = df['p_case_title'].apply(lambda X: word_tokenize(X))
df['p_case_text'] = df['p_case_text'].apply(lambda X: word_tokenize(X))
df.head(10)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#   case_id case_outcome                                         case_title  \
# 0   Case1        cited  Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1   Case2        cited  Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2   Case3        cited  Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3   Case4        cited  Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4   Case5        cited  Dr Martens Australia Pty Ltd v Figgins Holding...
# 5   Case6        cited  GEC Marconi Systems Pty Ltd v BHP Information ...
# 6   Case7        cited  John S Hayes &amp; Associates Pty Ltd v Kimber...
# 7   Case8        cited  Seven Network Limited v News Limited (2007) 24...
# 8   Case9      applied  Australian Broadcasting Corporation v O'Neill ...
# 9  Case10     followed  Hexal Australia Pty Ltd v Roche Therapeutics I...
#
#                                            case_text  \
# 0  Ordinarily that discretion will be exercised s...
# 1  The general principles governing the exercise ...
# 2  Ordinarily that discretion will be exercised s...
# 3  The general principles governing the exercise ...
# 4  The preceding general principles inform the ex...
# 5  I accept that the making of a rolled up offer ...
# 6  The preceding general principles inform the ex...
# 7  On the question of the level of unreasonablene...
# 8  recent decision of the High Court in Australia...
# 9  Hexal Australia Pty Ltd v Roche Therapeutics I...
#
#                                         p_case_title  \
# 0  [alpine, hardwood, (, aust, ), pty, ltd, v, ha...
# 1  [black, v, lipovac, [, 1998, ], fca, 699, ;, (...
# 2  [colgate, palmolive, co, v, cussons, pty, ltd,...
# 3  [dais, studio, pty, ltd, v, bullett, creative,...
# 4  [dr, martens, australia, pty, ltd, v, figgins,...
# 5  [gec, marconi, systems, pty, ltd, v, bhp, info...
# 6  [john, s, hayes, &, amp, ;, associates, pty, l...
# 7  [seven, network, limited, v, news, limited, (,...
# 8  [australian, broadcasting, corporation, v, o'n...
# 9  [hexal, australia, pty, ltd, v, roche, therape...
#
#                                          p_case_text
# 0  [ordinarily, that, discretion, will, be, exerc...
# 1  [the, general, principles, governing, the, exe...
# 2  [ordinarily, that, discretion, will, be, exerc...
# 3  [the, general, principles, governing, the, exe...
# 4  [the, preceding, general, principles, inform, ...
# 5  [i, accept, that, the, making, of, a, rolled, ...
# 6  [the, preceding, general, principles, inform, ...
# 7  [on, the, question, of, the, level, of, unreas...
# 8  [recent, decision, of, the, high, court, in, a...
# 9  [hexal, australia, pty, ltd, v, roche, therape...

# %%
# Remove punctuation

from nltk.tokenize import RegexpTokenizer

def remove_punct(textt):
    tokenizer = RegexpTokenizer(r"\w+")
    case_title = tokenizer.tokenize(' '.join(textt))
    return case_title

df['p_case_title'] = df['p_case_title'].apply(lambda X: remove_punct(X))
df['p_case_text'] = df['p_case_text'].apply(lambda X: remove_punct(X))
df.head(10)
# Out:
#   case_id case_outcome                                         case_title  \
# 0   Case1        cited  Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1   Case2        cited  Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2   Case3        cited  Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3   Case4        cited  Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4   Case5        cited  Dr Martens Australia Pty Ltd v Figgins Holding...
# 5   Case6        cited  GEC Marconi Systems Pty Ltd v BHP Information ...
# 6   Case7        cited  John S Hayes &amp; Associates Pty Ltd v Kimber...
# 7   Case8        cited  Seven Network Limited v News Limited (2007) 24...
# 8   Case9      applied  Australian Broadcasting Corporation v O'Neill ...
# 9  Case10     followed  Hexal Australia Pty Ltd v Roche Therapeutics I...
#
#                                            case_text  \
# 0  Ordinarily that discretion will be exercised s...
# 1  The general principles governing the exercise ...
# 2  Ordinarily that discretion will be exercised s...
# 3  The general principles governing the exercise ...
# 4  The preceding general principles inform the ex...
# 5  I accept that the making of a rolled up offer ...
# 6  The preceding general principles inform the ex...
# 7  On the question of the level of unreasonablene...
# 8  recent decision of the High Court in Australia...
# 9  Hexal Australia Pty Ltd v Roche Therapeutics I...
#
#                                         p_case_title  \
# 0  [alpine, hardwood, aust, pty, ltd, v, hardys, ...
# 1  [black, v, lipovac, 1998, fca, 699, 1998, 217,...
# 2  [colgate, palmolive, co, v, cussons, pty, ltd,...
# 3  [dais, studio, pty, ltd, v, bullett, creative,...
# 4  [dr, martens, australia, pty, ltd, v, figgins,...
# 5  [gec, marconi, systems, pty, ltd, v, bhp, info...
# 6  [john, s, hayes, amp, associates, pty, ltd, v,...
# 7  [seven, network, limited, v, news, limited, 20...
# 8  [australian, broadcasting, corporation, v, o, ...
# 9  [hexal, australia, pty, ltd, v, roche, therape...
#
#                                          p_case_text
# 0  [ordinarily, that, discretion, will, be, exerc...
# 1  [the, general, principles, governing, the, exe...
# 2  [ordinarily, that, discretion, will, be, exerc...
# 3  [the, general, principles, governing, the, exe...
# 4  [the, preceding, general, principles, inform, ...
# 5  [i, accept, that, the, making, of, a, rolled, ...
# 6  [the, preceding, general, principles, inform, ...
# 7  [on, the, question, of, the, level, of, unreas...
# 8  [recent, decision, of, the, high, court, in, a...
# 9  [hexal, australia, pty, ltd, v, roche, therape...

# %%
# Lemmatize

#from nltk.stem import WordNetLemmatizer
#from nltk import word_tokenize, pos_tag

#def lemmatize(textt):
#    lemmatizer = WordNetLemmatizer()
#    case_title = [lemmatizer.lemmatize(word) for word in textt]
#    return case_title

# %%
df['pr_case_title'] = df['case_title'].apply(nlp)

df
# Out:
#          case_id   case_outcome  \
# 0          Case1          cited
# 1          Case2          cited
# 2          Case3          cited
# 3          Case4          cited
# 4          Case5          cited
# ...          ...            ...
# 24980  Case25203          cited
# 24981  Case25204          cited
# 24982  Case25205          cited
# 24983  Case25206  distinguished
# 24984  Case25207  distinguished
#
#                                               case_title  \
# 0      Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1      Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2      Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3      Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4      Dr Martens Australia Pty Ltd v Figgins Holding...
# ...                                                  ...
# 24980  Reches Pty Ltd v Tadiran Pty Ltd (1998) 85 FCR...
# 24981  Sir Lindsay Parkinson &amp; Co Ltd v Triplan L...
# 24982  Spiel v Commodity Brokers Australia Pty Ltd (I...
# 24983  Tullock Ltd v Walker (Unreported, Supreme Cour...
# 24984  Yandil Holdings Pty Ltd v Insurance Co of Nort...
#
#                                                case_text  \
# 0      Ordinarily that discretion will be exercised s...
# 1      The general principles governing the exercise ...
# 2      Ordinarily that discretion will be exercised s...
# 3      The general principles governing the exercise ...
# 4      The preceding general principles inform the ex...
# ...                                                  ...
# 24980  That is not confined to persons who control th...
# 24981  Once the threshold prescribed by s 1335 is sat...
# 24982  Once the threshold prescribed by s 1335 is sat...
# 24983  Given the extent to which Deumer stands to gai...
# 24984  In my view, it is clear that the Court may do ...
#
#                                             p_case_title  \
# 0      [alpine, hardwood, aust, pty, ltd, v, hardys, ...
# 1      [black, v, lipovac, 1998, fca, 699, 1998, 217,...
# 2      [colgate, palmolive, co, v, cussons, pty, ltd,...
# 3      [dais, studio, pty, ltd, v, bullett, creative,...
# 4      [dr, martens, australia, pty, ltd, v, figgins,...
# ...                                                  ...
# 24980  [reches, pty, ltd, v, tadiran, pty, ltd, 1998,...
# 24981  [sir, lindsay, parkinson, amp, co, ltd, v, tri...
# 24982  [spiel, v, commodity, brokers, australia, pty,...
# 24983  [tullock, ltd, v, walker, unreported, supreme,...
# 24984  [yandil, holdings, pty, ltd, v, insurance, co,...
#
#                                              p_case_text  \
# 0      [ordinarily, that, discretion, will, be, exerc...
# 1      [the, general, principles, governing, the, exe...
# 2      [ordinarily, that, discretion, will, be, exerc...
# 3      [the, general, principles, governing, the, exe...
# 4      [the, preceding, general, principles, inform, ...
# ...                                                  ...
# 24980  [that, is, not, confined, to, persons, who, co...
# 24981  [once, the, threshold, prescribed, by, s, 1335...
# 24982  [once, the, threshold, prescribed, by, s, 1335...
# 24983  [given, the, extent, to, which, deumer, stands...
# 24984  [in, my, view, it, is, clear, that, the, court...
#
#                                            pr_case_title
# 0      (Alpine, Hardwood, (, Aust, ), Pty, Ltd, v, Ha...
# 1      (Black, v, Lipovac, [, 1998, ], FCA, 699, ;, (...
# 2      (Colgate, Palmolive, Co, v, Cussons, Pty, Ltd,...
# 3      (Dais, Studio, Pty, Ltd, v, Bullett, Creative,...
# 4      (Dr, Martens, Australia, Pty, Ltd, v, Figgins,...
# ...                                                  ...
# 24980  (Reches, Pty, Ltd, v, Tadiran, Pty, Ltd, (, 19...
# 24981  (Sir, Lindsay, Parkinson, &, amp, ;, Co, Ltd, ...
# 24982  (Spiel, v, Commodity, Brokers, Australia, Pty,...
# 24983  (Tullock, Ltd, v, Walker, (, Unreported, ,, Su...
# 24984  (Yandil, Holdings, Pty, Ltd, v, Insurance, Co,...
#
# [24809 rows x 7 columns]

# %%
df['pr_case_text'] = df['case_text'].apply(nlp)

df
# Out:
#          case_id   case_outcome  \
# 0          Case1          cited
# 1          Case2          cited
# 2          Case3          cited
# 3          Case4          cited
# 4          Case5          cited
# ...          ...            ...
# 24980  Case25203          cited
# 24981  Case25204          cited
# 24982  Case25205          cited
# 24983  Case25206  distinguished
# 24984  Case25207  distinguished
#
#                                               case_title  \
# 0      Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1      Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2      Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3      Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4      Dr Martens Australia Pty Ltd v Figgins Holding...
# ...                                                  ...
# 24980  Reches Pty Ltd v Tadiran Pty Ltd (1998) 85 FCR...
# 24981  Sir Lindsay Parkinson &amp; Co Ltd v Triplan L...
# 24982  Spiel v Commodity Brokers Australia Pty Ltd (I...
# 24983  Tullock Ltd v Walker (Unreported, Supreme Cour...
# 24984  Yandil Holdings Pty Ltd v Insurance Co of Nort...
#
#                                                case_text  \
# 0      Ordinarily that discretion will be exercised s...
# 1      The general principles governing the exercise ...
# 2      Ordinarily that discretion will be exercised s...
# 3      The general principles governing the exercise ...
# 4      The preceding general principles inform the ex...
# ...                                                  ...
# 24980  That is not confined to persons who control th...
# 24981  Once the threshold prescribed by s 1335 is sat...
# 24982  Once the threshold prescribed by s 1335 is sat...
# 24983  Given the extent to which Deumer stands to gai...
# 24984  In my view, it is clear that the Court may do ...
#
#                                             p_case_title  \
# 0      [alpine, hardwood, aust, pty, ltd, v, hardys, ...
# 1      [black, v, lipovac, 1998, fca, 699, 1998, 217,...
# 2      [colgate, palmolive, co, v, cussons, pty, ltd,...
# 3      [dais, studio, pty, ltd, v, bullett, creative,...
# 4      [dr, martens, australia, pty, ltd, v, figgins,...
# ...                                                  ...
# 24980  [reches, pty, ltd, v, tadiran, pty, ltd, 1998,...
# 24981  [sir, lindsay, parkinson, amp, co, ltd, v, tri...
# 24982  [spiel, v, commodity, brokers, australia, pty,...
# 24983  [tullock, ltd, v, walker, unreported, supreme,...
# 24984  [yandil, holdings, pty, ltd, v, insurance, co,...
#
#                                              p_case_text  \
# 0      [ordinarily, that, discretion, will, be, exerc...
# 1      [the, general, principles, governing, the, exe...
# 2      [ordinarily, that, discretion, will, be, exerc...
# 3      [the, general, principles, governing, the, exe...
# 4      [the, preceding, general, principles, inform, ...
# ...                                                  ...
# 24980  [that, is, not, confined, to, persons, who, co...
# 24981  [once, the, threshold, prescribed, by, s, 1335...
# 24982  [once, the, threshold, prescribed, by, s, 1335...
# 24983  [given, the, extent, to, which, deumer, stands...
# 24984  [in, my, view, it, is, clear, that, the, court...
#
#                                            pr_case_title nouns  \
# 0      (Alpine, Hardwood, (, Aust, ), Pty, Ltd, v, Ha...    []
# 1      (Black, v, Lipovac, [, 1998, ], FCA, 699, ;, (...    []
# 2      (Colgate, Palmolive, Co, v, Cussons, Pty, Ltd,...    []
# 3      (Dais, Studio, Pty, Ltd, v, Bullett, Creative,...    []
# 4      (Dr, Martens, Australia, Pty, Ltd, v, Figgins,...    []
# ...                                                  ...   ...
# 24980  (Reches, Pty, Ltd, v, Tadiran, Pty, Ltd, (, 19...    []
# 24981  (Sir, Lindsay, Parkinson, &, amp, ;, Co, Ltd, ...    []
# 24982  (Spiel, v, Commodity, Brokers, Australia, Pty,...    []
# 24983  (Tullock, Ltd, v, Walker, (, Unreported, ,, Su...    []
# 24984  (Yandil, Holdings, Pty, Ltd, v, Insurance, Co,...    []
#
#                                             pr_case_text
# 0      (Ordinarily, that, discretion, will, be, exerc...
# 1      (The, general, principles, governing, the, exe...
# 2      (Ordinarily, that, discretion, will, be, exerc...
# 3      (The, general, principles, governing, the, exe...
# 4      (The, preceding, general, principles, inform, ...
# ...                                                  ...
# 24980  (That, is, not, confined, to, persons, who, co...
# 24981  (Once, the, threshold, prescribed, by, s, 1335...
# 24982  (Once, the, threshold, prescribed, by, s, 1335...
# 24983  (Given, the, extent, to, which, Deumer, stands...
# 24984  (In, my, view, ,, it, is, clear, that, the, Co...
#
# [24809 rows x 9 columns]

# %%
# Get nouns from the text

def get_nouns(nlp_text):
    assert type(nlp_text) == spacy.tokens.doc.Doc
    lemmas = []
    for token in nlp_text:
        if token.pos_ == 'NN':
            lemmas.append(token.lemma_)
    return lemmas

#def get_nouns(text):
#    doc = nlp(text)
#    nouns = [token.lemma_ for token in doc if token.pos_ == 'NOUN']
#    return nouns

# %%
# Apply get nouns function
df['nouns'] = df['pr_case_title'].apply(get_nouns)
df
# Out:
#          case_id   case_outcome  \
# 0          Case1          cited
# 1          Case2          cited
# 2          Case3          cited
# 3          Case4          cited
# 4          Case5          cited
# ...          ...            ...
# 24980  Case25203          cited
# 24981  Case25204          cited
# 24982  Case25205          cited
# 24983  Case25206  distinguished
# 24984  Case25207  distinguished
#
#                                               case_title  \
# 0      Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1      Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2      Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3      Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4      Dr Martens Australia Pty Ltd v Figgins Holding...
# ...                                                  ...
# 24980  Reches Pty Ltd v Tadiran Pty Ltd (1998) 85 FCR...
# 24981  Sir Lindsay Parkinson &amp; Co Ltd v Triplan L...
# 24982  Spiel v Commodity Brokers Australia Pty Ltd (I...
# 24983  Tullock Ltd v Walker (Unreported, Supreme Cour...
# 24984  Yandil Holdings Pty Ltd v Insurance Co of Nort...
#
#                                                case_text  \
# 0      Ordinarily that discretion will be exercised s...
# 1      The general principles governing the exercise ...
# 2      Ordinarily that discretion will be exercised s...
# 3      The general principles governing the exercise ...
# 4      The preceding general principles inform the ex...
# ...                                                  ...
# 24980  That is not confined to persons who control th...
# 24981  Once the threshold prescribed by s 1335 is sat...
# 24982  Once the threshold prescribed by s 1335 is sat...
# 24983  Given the extent to which Deumer stands to gai...
# 24984  In my view, it is clear that the Court may do ...
#
#                                             p_case_title  \
# 0      [alpine, hardwood, aust, pty, ltd, v, hardys, ...
# 1      [black, v, lipovac, 1998, fca, 699, 1998, 217,...
# 2      [colgate, palmolive, co, v, cussons, pty, ltd,...
# 3      [dais, studio, pty, ltd, v, bullett, creative,...
# 4      [dr, martens, australia, pty, ltd, v, figgins,...
# ...                                                  ...
# 24980  [reches, pty, ltd, v, tadiran, pty, ltd, 1998,...
# 24981  [sir, lindsay, parkinson, amp, co, ltd, v, tri...
# 24982  [spiel, v, commodity, brokers, australia, pty,...
# 24983  [tullock, ltd, v, walker, unreported, supreme,...
# 24984  [yandil, holdings, pty, ltd, v, insurance, co,...
#
#                                              p_case_text  \
# 0      [ordinarily, that, discretion, will, be, exerc...
# 1      [the, general, principles, governing, the, exe...
# 2      [ordinarily, that, discretion, will, be, exerc...
# 3      [the, general, principles, governing, the, exe...
# 4      [the, preceding, general, principles, inform, ...
# ...                                                  ...
# 24980  [that, is, not, confined, to, persons, who, co...
# 24981  [once, the, threshold, prescribed, by, s, 1335...
# 24982  [once, the, threshold, prescribed, by, s, 1335...
# 24983  [given, the, extent, to, which, deumer, stands...
# 24984  [in, my, view, it, is, clear, that, the, court...
#
#                                            pr_case_title nouns
# 0      (Alpine, Hardwood, (, Aust, ), Pty, Ltd, v, Ha...    []
# 1      (Black, v, Lipovac, [, 1998, ], FCA, 699, ;, (...    []
# 2      (Colgate, Palmolive, Co, v, Cussons, Pty, Ltd,...    []
# 3      (Dais, Studio, Pty, Ltd, v, Bullett, Creative,...    []
# 4      (Dr, Martens, Australia, Pty, Ltd, v, Figgins,...    []
# ...                                                  ...   ...
# 24980  (Reches, Pty, Ltd, v, Tadiran, Pty, Ltd, (, 19...    []
# 24981  (Sir, Lindsay, Parkinson, &, amp, ;, Co, Ltd, ...    []
# 24982  (Spiel, v, Commodity, Brokers, Australia, Pty,...    []
# 24983  (Tullock, Ltd, v, Walker, (, Unreported, ,, Su...    []
# 24984  (Yandil, Holdings, Pty, Ltd, v, Insurance, Co,...    []
#
# [24809 rows x 8 columns]

# %%
# Apply get nouns function
df['nouns_text'] = df['pr_case_text'].apply(get_nouns)
df
# Out:
#          case_id   case_outcome  \
# 0          Case1          cited
# 1          Case2          cited
# 2          Case3          cited
# 3          Case4          cited
# 4          Case5          cited
# ...          ...            ...
# 24980  Case25203          cited
# 24981  Case25204          cited
# 24982  Case25205          cited
# 24983  Case25206  distinguished
# 24984  Case25207  distinguished
#
#                                               case_title  \
# 0      Alpine Hardwood (Aust) Pty Ltd v Hardys Pty Lt...
# 1      Black v Lipovac [1998] FCA 699 ; (1998) 217 AL...
# 2      Colgate Palmolive Co v Cussons Pty Ltd (1993) ...
# 3      Dais Studio Pty Ltd v Bullett Creative Pty Ltd...
# 4      Dr Martens Australia Pty Ltd v Figgins Holding...
# ...                                                  ...
# 24980  Reches Pty Ltd v Tadiran Pty Ltd (1998) 85 FCR...
# 24981  Sir Lindsay Parkinson &amp; Co Ltd v Triplan L...
# 24982  Spiel v Commodity Brokers Australia Pty Ltd (I...
# 24983  Tullock Ltd v Walker (Unreported, Supreme Cour...
# 24984  Yandil Holdings Pty Ltd v Insurance Co of Nort...
#
#                                                case_text  \
# 0      Ordinarily that discretion will be exercised s...
# 1      The general principles governing the exercise ...
# 2      Ordinarily that discretion will be exercised s...
# 3      The general principles governing the exercise ...
# 4      The preceding general principles inform the ex...
# ...                                                  ...
# 24980  That is not confined to persons who control th...
# 24981  Once the threshold prescribed by s 1335 is sat...
# 24982  Once the threshold prescribed by s 1335 is sat...
# 24983  Given the extent to which Deumer stands to gai...
# 24984  In my view, it is clear that the Court may do ...
#
#                                             p_case_title  \
# 0      [alpine, hardwood, aust, pty, ltd, v, hardys, ...
# 1      [black, v, lipovac, 1998, fca, 699, 1998, 217,...
# 2      [colgate, palmolive, co, v, cussons, pty, ltd,...
# 3      [dais, studio, pty, ltd, v, bullett, creative,...
# 4      [dr, martens, australia, pty, ltd, v, figgins,...
# ...                                                  ...
# 24980  [reches, pty, ltd, v, tadiran, pty, ltd, 1998,...
# 24981  [sir, lindsay, parkinson, amp, co, ltd, v, tri...
# 24982  [spiel, v, commodity, brokers, australia, pty,...
# 24983  [tullock, ltd, v, walker, unreported, supreme,...
# 24984  [yandil, holdings, pty, ltd, v, insurance, co,...
#
#                                              p_case_text  \
# 0      [ordinarily, that, discretion, will, be, exerc...
# 1      [the, general, principles, governing, the, exe...
# 2      [ordinarily, that, discretion, will, be, exerc...
# 3      [the, general, principles, governing, the, exe...
# 4      [the, preceding, general, principles, inform, ...
# ...                                                  ...
# 24980  [that, is, not, confined, to, persons, who, co...
# 24981  [once, the, threshold, prescribed, by, s, 1335...
# 24982  [once, the, threshold, prescribed, by, s, 1335...
# 24983  [given, the, extent, to, which, deumer, stands...
# 24984  [in, my, view, it, is, clear, that, the, court...
#
#                                            pr_case_title nouns  \
# 0      (Alpine, Hardwood, (, Aust, ), Pty, Ltd, v, Ha...    []
# 1      (Black, v, Lipovac, [, 1998, ], FCA, 699, ;, (...    []
# 2      (Colgate, Palmolive, Co, v, Cussons, Pty, Ltd,...    []
# 3      (Dais, Studio, Pty, Ltd, v, Bullett, Creative,...    []
# 4      (Dr, Martens, Australia, Pty, Ltd, v, Figgins,...    []
# ...                                                  ...   ...
# 24980  (Reches, Pty, Ltd, v, Tadiran, Pty, Ltd, (, 19...    []
# 24981  (Sir, Lindsay, Parkinson, &, amp, ;, Co, Ltd, ...    []
# 24982  (Spiel, v, Commodity, Brokers, Australia, Pty,...    []
# 24983  (Tullock, Ltd, v, Walker, (, Unreported, ,, Su...    []
# 24984  (Yandil, Holdings, Pty, Ltd, v, Insurance, Co,...    []
#
#                                             pr_case_text nouns_text
# 0      (Ordinarily, that, discretion, will, be, exerc...         []
# 1      (The, general, principles, governing, the, exe...         []
# 2      (Ordinarily, that, discretion, will, be, exerc...         []
# 3      (The, general, principles, governing, the, exe...         []
# 4      (The, preceding, general, principles, inform, ...         []
# ...                                                  ...        ...
# 24980  (That, is, not, confined, to, persons, who, co...         []
# 24981  (Once, the, threshold, prescribed, by, s, 1335...         []
# 24982  (Once, the, threshold, prescribed, by, s, 1335...         []
# 24983  (Given, the, extent, to, which, Deumer, stands...         []
# 24984  (In, my, view, ,, it, is, clear, that, the, Co...         []
#
# [24809 rows x 10 columns]

# %%
# Extract nouns into a list
noun_list = df['nouns_text'].tolist()
noun_list[:10]
# Out:
# [[], [], [], [], [], [], [], [], [], []]
